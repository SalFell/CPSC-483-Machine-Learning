# %% [markdown]
# <a href="https://colab.research.google.com/github/SalFell/CPSC-483-Machine-Learning/blob/main/Discussion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive,files
import numpy as np
import pandas as pd
import ipywidgets as widgets
import matplotlib.pyplot as plt
import sklearn.linear_model
drive.mount('/content/drive/')
#uploaded = files.upload()

hls_all_raw = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HSL_08022024200038350.csv")

#print(hls_all_raw["Indicator"])
print("\n1===========================================================\n")
hls_slice = pd.DataFrame(hls_all_raw, columns =["Country","Indicator","Type of indicator","Time","Value"])
#print(hls_slice)
#
hls_ls = hls_slice.loc[hls_all_raw["Indicator"] == "Employment rate"]
print(hls_ls)
print("\n2===========================================================\n")
print("Total records:")
print(len(hls_ls))

print("\n3===========================================================\n")
print("Total Unique Countries:")
print(len(hls_ls["Country"].unique()))

print("\n4===========================================================\n")
print("Country List")
print(hls_ls["Country"].unique())
#
hls_train = hls_ls.loc[hls_ls["Time"] == 2021]
#hls_train = hls_ls.loc[hls_ls["Time"] >= 2018]
hls_train = hls_train.loc[hls_ls["Type of indicator"] == "Average"]
print("\n5===========================================================\n")
print("Total records:")
print(len(hls_train))

print("\n6===========================================================\n")
print("Total Unique Countries:")
print(len(hls_train["Country"].unique()))

print("\n7===========================================================\n")
print("Record:")
print(hls_train)

#
weo_raw = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/WEOOct2023all.xls", sep='\t', encoding='latin1')
#
weo_selected_measurement = weo_raw.loc[weo_raw['WEO Subject Code'].str.contains("NGDP_RPCH", na=False)]
weo_selected_measurement_2018 = pd.DataFrame(weo_selected_measurement, columns=['Country', '2018'])

print(weo_selected_measurement_2018)

#
merged_train_data = pd.merge(hls_train, weo_selected_measurement_2018, on="Country")
merged_train_data = merged_train_data.rename(columns={"Value": "Happiness Measurement", "2018": "Employment Measurement"})
merged_train_data = pd.DataFrame(merged_train_data, columns=['Country','Happiness Measurement', 'Employment Measurement'])

print(merged_train_data)

#
X = np.c_[merged_train_data["Employment Measurement"]]
Y = np.c_[merged_train_data["Happiness Measurement"]]
x = X.tolist()
y = Y.tolist()

# plot data
out1 = widgets.Output()
with out1:
  plt.scatter(x, y)
  plt.xlabel('Employment')
  plt.ylabel('Happiness')
  plt.title("Data Plot")
  plt.show()

# fit linear model
model = sklearn.linear_model.LinearRegression()
model.fit(X, Y)

# plot predictions
predict_x = [x for x in range(901)]
predict_x = [[x/100] for x in predict_x]
predict_y = model.predict(predict_x)

out2 = widgets.Output()
with out2:
  plt.scatter(predict_x, predict_y)
  plt.scatter(x, y)
  plt.xlabel('Employment')
  plt.ylabel('Happiness')
  plt.title("Prediction Line")
  plt.show()

display(widgets.HBox([out1,out2]))
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#
# 1===========================================================
#
#             Country        Indicator Type of indicator  Time      Value
# 21        Australia  Employment rate           Average  2004  72.397004
# 22        Australia  Employment rate           Average  2005  73.679393
# 23        Australia  Employment rate           Average  2006  74.308828
# 24        Australia  Employment rate           Average  2007  75.057021
# 25        Australia  Employment rate           Average  2008  75.475192
# ...             ...              ...               ...   ...        ...
# 12048  South Africa  Employment rate           Average  2017  55.148640
# 12049  South Africa  Employment rate           Average  2018  54.971014
# 12050  South Africa  Employment rate           Average  2019  53.920095
# 12051  South Africa  Employment rate           Average  2020  49.210919
# 12052  South Africa  Employment rate           Average  2021  47.253083
#
# [736 rows x 5 columns]
#
# 2===========================================================
#
# Total records:
# 736
#
# 3===========================================================
#
# Total Unique Countries:
# 41
#
# 4===========================================================
#
# Country List
# ['Australia' 'Austria' 'Belgium' 'Canada' 'Czechia' 'Denmark' 'Finland'
#  'France' 'Germany' 'Greece' 'Hungary' 'Iceland' 'Ireland' 'Italy' 'Japan'
#  'Korea' 'Luxembourg' 'Mexico' 'Netherlands' 'New Zealand' 'Norway'
#  'Poland' 'Portugal' 'Slovak Republic' 'Spain' 'Sweden' 'Switzerland'
#  'Türkiye' 'United Kingdom' 'United States' 'Brazil' 'Chile' 'Colombia'
#  'Costa Rica' 'Estonia' 'Israel' 'Latvia' 'Lithuania' 'Russia' 'Slovenia'
#  'South Africa']
#
# 5===========================================================
#
# Total records:
# 41
#
# 6===========================================================
#
# Total Unique Countries:
# 41
#
# 7===========================================================
#
# Record:
#                Country        Indicator Type of indicator  Time      Value
# 38           Australia  Employment rate           Average  2021  78.213634
# 318            Austria  Employment rate           Average  2021  76.428466
# 667            Belgium  Employment rate           Average  2021  74.057447
# 986             Canada  Employment rate           Average  2021  77.222668
# 1317           Czechia  Employment rate           Average  2021  82.700911
# 1654           Denmark  Employment rate           Average  2021  80.750266
# 2000           Finland  Employment rate           Average  2021  78.719682
# 2346            France  Employment rate           Average  2021  75.389066
# 2680           Germany  Employment rate           Average  2021  80.840373
# 3025            Greece  Employment rate           Average  2021  65.389310
# 3369           Hungary  Employment rate           Average  2021  81.650777
# 3696           Iceland  Employment rate           Average  2021  82.749649
# 3989           Ireland  Employment rate           Average  2021  76.915178
# 4328             Italy  Employment rate           Average  2021  65.622464
# 4676             Japan  Employment rate           Average  2021  83.620274
# 4957             Korea  Employment rate           Average  2021  72.995803
# 5251        Luxembourg  Employment rate           Average  2021  77.055346
# 5549            Mexico  Employment rate           Average  2021  67.824479
# 5821       Netherlands  Employment rate           Average  2021  82.109384
# 6164       New Zealand  Employment rate           Average  2021  83.233624
# 6445            Norway  Employment rate           Average  2021  81.498763
# 6768            Poland  Employment rate           Average  2021  77.698713
# 7123          Portugal  Employment rate           Average  2021  79.585039
# 7450   Slovak Republic  Employment rate           Average  2021  78.023669
# 7756             Spain  Employment rate           Average  2021  70.529342
# 8107            Sweden  Employment rate           Average  2021  82.938406
# 8446       Switzerland  Employment rate           Average  2021  82.880739
# 8710           Türkiye  Employment rate           Average  2021  55.149486
# 9002    United Kingdom  Employment rate           Average  2021  79.330242
# 9340     United States  Employment rate           Average  2021  73.680012
# 9636            Brazil  Employment rate           Average  2021  65.033162
# 9754             Chile  Employment rate           Average  2021  67.624108
# 9980          Colombia  Employment rate           Average  2021  68.814119
# 10192       Costa Rica  Employment rate           Average  2021  66.129081
# 10368          Estonia  Employment rate           Average  2021  81.001886
# 10674           Israel  Employment rate           Average  2021  75.710728
# 10955           Latvia  Employment rate           Average  2021  77.074600
# 11266        Lithuania  Employment rate           Average  2021  79.870447
# 11584           Russia  Employment rate           Average  2021  79.250333
# 11726         Slovenia  Employment rate           Average  2021  78.985399
# 12052     South Africa  Employment rate           Average  2021  47.253083
#                  Country    2018
# 1            Afghanistan   1.189
# 45               Albania   4.019
# 89               Algeria     1.2
# 133              Andorra   1.589
# 177               Angola  -1.316
# ...                  ...     ...
# 8405             Vietnam   7.465
# 8449  West Bank and Gaza   1.227
# 8493               Yemen   0.752
# 8537              Zambia   4.035
# 8581            Zimbabwe   4.987
#
# [196 rows x 2 columns]
#             Country  Happiness Measurement Employment Measurement
# 0         Australia              78.213634                  2.815
# 1           Austria              76.428466                  2.425
# 2           Belgium              74.057447                  1.793
# 3            Canada              77.222668                  2.777
# 4           Denmark              80.750266                  1.991
# 5           Finland              78.719682                   1.14
# 6            France              75.389066                  1.818
# 7           Germany              80.840373                  0.984
# 8            Greece              65.389310                  1.668
# 9           Hungary              81.650777                  5.362
# 10          Iceland              82.749649                  4.889
# 11          Ireland              76.915178                  8.471
# 12            Italy              65.622464                  0.926
# 13            Japan              83.620274                  0.643
# 14            Korea              72.995803                  2.907
# 15       Luxembourg              77.055346                  1.219
# 16           Mexico              67.824479                  1.972
# 17      Netherlands              82.109384                  2.361
# 18      New Zealand              83.233624                  3.524
# 19           Norway              81.498763                  0.829
# 20           Poland              77.698713                  5.945
# 21         Portugal              79.585039                  2.849
# 22  Slovak Republic              78.023669                  4.031
# 23            Spain              70.529342                  2.283
# 24           Sweden              82.938406                   1.95
# 25      Switzerland              82.880739                  2.856
# 26          Türkiye              55.149486                  3.013
# 27   United Kingdom              79.330242                  1.705
# 28    United States              73.680012                  2.945
# 29           Brazil              65.033162                  1.784
# 30            Chile              67.624108                   3.99
# 31         Colombia              68.814119                  2.565
# 32       Costa Rica              66.129081                  2.616
# 33          Estonia              81.001886                  3.784
# 34           Israel              75.710728                  4.075
# 35           Latvia              77.074600                  3.992
# 36        Lithuania              79.870447                  3.993
# 37           Russia              79.250333                  2.806
# 38         Slovenia              78.985399                  4.454
# 39     South Africa              47.253083                  1.557
# HBox(children=(Output(), Output()))
